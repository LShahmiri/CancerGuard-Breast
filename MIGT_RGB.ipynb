# %% [markdown]
# MIGT-RGB

# %%
pip install migt

# %%
from migt import MIGTSplitter

splitter = MIGTSplitter(
    dataset_root="/DATASETS/cancer/BreaKHis_final/",   # path containing class folders
    bins=4,                                  # maximum number of MI bins
    min_bin=10,                              # minimum samples per bin
    train=0.5,                               # 70% training
    test=0.4,                                # 20% testing
    val=0.1,                                 # 10% validation (optional)
    strict_shape=False,                      # allow different image sizes
    resize_to=(224, 224),                    # resize images before MI
    mode="color",                      # MI computation mode
    seed=42,
    verbose=False
)

splitter.run(
    output_root="/DATASETS/cancer/migt-color/"
)

# %%
# -------------------- Imports --------------------
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# -------------------- Mount Google Drive --------------------
from google.colab import drive
drive.mount("/content/drive")

# -------------------- Configuration --------------------
BASE_DIR = "/content/drive/MyDrive/DATASETS/cancer/migt/"  # change if needed

TRAIN_DIR = os.path.join(BASE_DIR, "train")
VAL_DIR   = os.path.join(BASE_DIR, "val")
TEST_DIR  = os.path.join(BASE_DIR, "test")

IMG_SIZE = (224, 224)   # Xception expects 224x224
BATCH_SIZE = 32
EPOCHS = 100
PATIENCE = 6
SEED = 42

# Fine-tuning config
DO_FINE_TUNE = True
FINE_TUNE_LAYERS = 30         # unfreeze last N layers of Xception
HEAD_LR = 1e-3
FINE_TUNE_LR = 1e-5
FINE_TUNE_EPOCHS = 20         # additional epochs after head training

# -------------------- Model save paths (.keras) --------------------
SAVE_DIR = "/MIGT-Save"
os.makedirs(SAVE_DIR, exist_ok=True)

BASE_MODEL_PATH = os.path.join(SAVE_DIR, "xception_base_model.keras")
FULL_MODEL_PATH = os.path.join(SAVE_DIR, "xception_full_model.keras")
BEST_MODEL_PATH = os.path.join(SAVE_DIR, "xception_best_model.keras")  # <-- IMPORTANT

# -------------------- Safety Checks --------------------
for d in [TRAIN_DIR, VAL_DIR, TEST_DIR]:
    if not os.path.isdir(d):
        raise FileNotFoundError(
            f"Missing folder: {d}\n\n"
            "Expected structure:\n"
            "BASE_DIR/train/<class_name>/...\n"
            "BASE_DIR/val/<class_name>/...\n"
            "BASE_DIR/test/<class_name>/...\n"
        )

# -------------------- Load Datasets --------------------
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=False  # IMPORTANT for ROC/CM alignment
)

class_names = train_ds.class_names
print("Class names:", class_names)

# -------------------- Performance: Cache/Prefetch --------------------
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000, seed=SEED).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# -------------------- Data Augmentation --------------------
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.10),
        layers.RandomZoom(0.15),
        layers.RandomContrast(0.10),
    ],
    name="data_augmentation"
)

# Xception preprocess (ImageNet)
preprocess_input = tf.keras.applications.xception.preprocess_input

# -------------------- Build Model --------------------
base_model = tf.keras.applications.Xception(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

# Freeze base model for Stage 1 (train only head)
base_model.trainable = False

inputs = keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs, name="xception_cancer")

# -------------------- Compile (Stage 1: Train Head) --------------------
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=HEAD_LR),
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)

model.summary()

# -------------------- Callbacks (save BEST to .keras) --------------------
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=PATIENCE,
        restore_best_weights=True
    ),
    keras.callbacks.ModelCheckpoint(
        filepath=BEST_MODEL_PATH,
        monitor="val_loss",
        save_best_only=True
    )
]

# -------------------- Train (Stage 1) --------------------
history_head = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# -------------------- Fine-Tuning (Stage 2) --------------------
history_ft = None
if DO_FINE_TUNE:
    base_model.trainable = True

    # Freeze all layers first
    for layer in base_model.layers:
        layer.trainable = False

    # Unfreeze last N layers except BatchNorm
    for layer in base_model.layers[-FINE_TUNE_LAYERS:]:
        if isinstance(layer, layers.BatchNormalization):
            layer.trainable = False
        else:
            layer.trainable = True

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
        loss="binary_crossentropy",
        metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
    )

    print("\nStarting fine-tuning...\n")
    history_ft = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FINE_TUNE_EPOCHS,
        callbacks=callbacks
    )

# -------------------- Save Models (.keras) --------------------
# Save base model and full model
base_model.save(BASE_MODEL_PATH)
model.save(FULL_MODEL_PATH)

print(f"Saved base model: {BASE_MODEL_PATH}")
print(f"Saved full model: {FULL_MODEL_PATH}")
print(f"Best checkpoint (val_loss): {BEST_MODEL_PATH}")

# -------------------- Combine History (for plotting) --------------------
def merge_histories(h1, h2):
    out = {}
    for k in h1.history.keys():
        out[k] = list(h1.history[k])
    if h2 is not None:
        for k in h2.history.keys():
            out[k].extend(list(h2.history[k]))
    return out

hist = merge_histories(history_head, history_ft)

# -------------------- Plot Training Curves --------------------
plt.figure(figsize=(10, 4))
plt.plot(hist["loss"], label="Train Loss")
plt.plot(hist["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
plt.plot(hist["accuracy"], label="Train Accuracy")
plt.plot(hist["val_accuracy"], label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.show()

# -------------------- Evaluate on Test Set (IMPORTANT: load BEST model) --------------------
model = tf.keras.models.load_model(BEST_MODEL_PATH)  # <-- BEST validation checkpoint
test_loss, test_acc, test_auc = model.evaluate(test_ds, verbose=1)

print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test AUC: {test_auc:.4f}\n")

# -------------------- Predictions for Confusion Matrix / ROC --------------------
y_true = []
y_prob = []

for x_batch, y_batch in test_ds:
    probs = model.predict(x_batch, verbose=0).reshape(-1)
    y_prob.extend(probs.tolist())
    y_true.extend(y_batch.numpy().astype(int).reshape(-1).tolist())

y_true = np.array(y_true)
y_prob = np.array(y_prob)

threshold = 0.5
y_pred = (y_prob >= threshold).astype(int)

# -------------------- Confusion Matrix --------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5, 4))
plt.imshow(cm)
plt.title("Confusion Matrix (Test Set)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks([0, 1], class_names, rotation=20)
plt.yticks([0, 1], class_names)

for i in range(2):
    for j in range(2):
        plt.text(j, i, str(cm[i, j]), ha="center", va="center")

plt.colorbar()
plt.show()

print("Classification Report (Test Set):")
print(classification_report(y_true, y_pred, target_names=class_names))

# -------------------- ROC Curve --------------------
fpr, tpr, _ = roc_curve(y_true, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], linestyle="--", label="Random baseline")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Test Set)")
plt.legend()
plt.show()

# -------------------- One Example Inference --------------------
for images, labels in test_ds.take(1):
    img = images[0]
    true_label = int(labels[0].numpy())

    prob = float(model.predict(tf.expand_dims(img, 0), verbose=0)[0][0])
    pred_label = int(prob >= threshold)

    plt.figure(figsize=(4, 4))
    plt.imshow(img.numpy().astype("uint8"))
    plt.title(
        f"True: {class_names[true_label]} | Pred: {class_names[pred_label]} | Prob: {prob:.3f}"
    )
    plt.axis("off")
    plt.show()
    break
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 1012 files belonging to 2 classes.
# Found 198 files belonging to 2 classes.
# Found 803 files belonging to 2 classes.
# Class names: ['benign', 'malignant']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "xception_cancer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 7, 7, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         2,049 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,863,529 (79.59 MB)
#  Trainable params: 2,049 (8.00 KB)
#  Non-trainable params: 20,861,480 (79.58 MB)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 381s 9s/step - accuracy: 0.6529 - auc: 0.6304 - loss: 0.6113 - val_accuracy: 0.7727 - val_auc: 0.8150 - val_loss: 0.4862
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 329s 10s/step - accuracy: 0.8090 - auc: 0.8366 - loss: 0.4542 - val_accuracy: 0.8636 - val_auc: 0.8577 - val_loss: 0.4217
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 316s 10s/step - accuracy: 0.8228 - auc: 0.8554 - loss: 0.4304 - val_accuracy: 0.8586 - val_auc: 0.8720 - val_loss: 0.4019
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 288s 9s/step - accuracy: 0.8155 - auc: 0.8501 - loss: 0.4235 - val_accuracy: 0.8485 - val_auc: 0.8839 - val_loss: 0.3898
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 320s 10s/step - accuracy: 0.8364 - auc: 0.8812 - loss: 0.3983 - val_accuracy: 0.8485 - val_auc: 0.8853 - val_loss: 0.3843
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━
# Epoch 6/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 436s 12s/step - accuracy: 0.9319 - auc: 0.9794 - loss: 0.1760 - val_accuracy: 0.8889 - val_auc: 0.9622 - val_loss: 0.2674
# Epoch 7/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 437s 13s/step - accuracy: 0.9356 - auc: 0.9829 - loss: 0.1591 - val_accuracy: 0.9091 - val_auc: 0.9654 - val_loss: 0.2387
# Epoch 8/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 449s 14s/step - accuracy: 0.9477 - auc: 0.9872 - loss: 0.1386 - val_accuracy: 0.9141 - val_auc: 0.9677 - val_loss: 0.2277
# Epoch 9/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 443s 14s/step - accuracy: 0.9351 - auc: 0.9789 - loss: 0.1712 - val_accuracy: 0.9091 - val_auc: 0.9669 - val_loss: 0.2388
# Epoch 10/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 409s 12s/step - accuracy: 0.9330 - auc: 0.9826 - loss: 0.1594 - val_accuracy: 0.9141 - val_auc: 0.9712 - val_loss: 0.2110
# Epoch 11/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 401s 12s/step - accuracy: 0.9430 - auc: 0.9887 - loss: 0.1354 - val_accuracy: 0.9242 - val_auc: 0.9722 - val_loss: 0.1955
# Epoch 12/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 441s 12s/step - accuracy: 0.9380 - auc: 0.9867 - loss: 0.1448 - val_accuracy: 0.9141 - val_auc: 0.9777 - val_loss: 0.1996
# Epoch 13/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 467s 13s/step - accuracy: 0.9378 - auc: 0.9861 - loss: 0.1394 - val_accuracy: 0.9192 - val_auc: 0.9779 - val_loss: 0.1921
# Epoch 14/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 408s 12s/step - accuracy: 0.9396 - auc: 0.9844 - loss: 0.1417 - val_accuracy: 0.9091 - val_auc: 0.9771 - val_loss: 0.2147
# Epoch 15/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 436s 13s/step - accuracy: 0.9529 - auc: 0.9897 - loss: 0.1282 - val_accuracy: 0.9091 - val_auc: 0.9792 - val_loss: 0.2191
# Epoch 16/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 441s 13s/step - accuracy: 0.9593 - auc: 0.9942 - loss: 0.1064 - val_accuracy: 0.9242 - val_auc: 0.9751 - val_loss: 0.1899
# Epoch 17/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 435s 13s/step - accuracy: 0.9697 - auc: 0.9936 - loss: 0.0942 - val_accuracy: 0.9293 - val_auc: 0.9793 - val_loss: 0.1732
# Epoch 18/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 472s 14s/step - accuracy: 0.9627 - auc: 0.9943 - loss: 0.0997 - val_accuracy: 0.9242 - val_auc: 0.9804 - val_loss: 0.1652
# Epoch 19/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 421s 13s/step - accuracy: 0.9678 - auc: 0.9950 - loss: 0.0899 - val_accuracy: 0.9444 - val_auc: 0.9812 - val_loss: 0.1634
# Epoch 20/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 422s 13s/step - accuracy: 0.9645 - auc: 0.9945 - loss: 0.0907 - val_accuracy: 0.9343 - val_auc: 0.9783 - val_loss: 0.1709
# Saved base model: /MIGT-Save/xception_base_model.keras
# Saved full model: /MIGT-Save/xception_full_model.keras
# Best checkpoint (val_loss): /MIGT-Save/xception_best_model.keras
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 212s 8s/step - accuracy: 0.9161 - auc: 0.7166 - loss: 0.2282
#
# Test Loss: 0.1832
# Test Accuracy: 0.9352
# Test AUC: 0.9764
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#       benign       0.89      0.91      0.90       248
#    malignant       0.96      0.95      0.95       555
#
#     accuracy                           0.94       803
#    macro avg       0.92      0.93      0.92       803
# weighted avg       0.94      0.94      0.94       803
# /tmp/ipython-input-3797997658.py:284: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   true_label = int(labels[0].numpy())
