# %% [markdown]
# ## Randomly selected dataset

# %%
# -------------------- Imports --------------------
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# -------------------- Configuration --------------------
BASE_DIR = "/content/drive/MyDrive/DATASETS/cancer/BreaKHis_split"
TRAIN_DIR = os.path.join(BASE_DIR, "train")
VAL_DIR   = os.path.join(BASE_DIR, "val")
TEST_DIR  = os.path.join(BASE_DIR, "test")

IMG_SIZE = (224, 224)   # Xception expects 224x224
BATCH_SIZE = 32
EPOCHS = 100
PATIENCE = 6
SEED = 42

# Fine-tuning config
DO_FINE_TUNE = True
FINE_TUNE_LAYERS = 30         # unfreeze last N layers of Xception
HEAD_LR = 1e-3
FINE_TUNE_LR = 1e-5
FINE_TUNE_EPOCHS = 20         # additional epochs after head training

# Model save paths (Drive)
SAVE_DIR = "/content/drive/MyDrive/DATASETS/cancer/model-saved/random-save"
os.makedirs(SAVE_DIR, exist_ok=True)
BASE_MODEL_H5 = os.path.join(SAVE_DIR, "xception_base_model.h5")
FULL_MODEL_H5 = os.path.join(SAVE_DIR, "xception_full_model.h5")
BEST_MODEL_H5 = os.path.join(SAVE_DIR, "xception_best_model.h5")

# -------------------- Safety Checks --------------------
for d in [TRAIN_DIR, VAL_DIR, TEST_DIR]:
    if not os.path.isdir(d):
        raise FileNotFoundError(
            f"Missing folder: {d}\n\n"
            "Expected structure:\n"
            "BASE_DIR/train/<class_name>/...\n"
            "BASE_DIR/val/<class_name>/...\n"
            "BASE_DIR/test/<class_name>/...\n"
        )

# -------------------- Load Datasets --------------------
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"  # returns labels as 0/1
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=False  # IMPORTANT for correct ROC/CM alignment
)

class_names = train_ds.class_names
print("Class names:", class_names)



# -------------------- Performance: Cache/Prefetch --------------------
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000, seed=SEED).prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)
test_ds = test_ds.prefetch(AUTOTUNE)

# -------------------- Data Augmentation --------------------
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.10),
        layers.RandomZoom(0.15),
        layers.RandomContrast(0.10),
    ],
    name="data_augmentation"
)

# Xception preprocess (ImageNet)
preprocess_input = tf.keras.applications.xception.preprocess_input

# -------------------- Build Model --------------------
base_model = tf.keras.applications.Xception(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

# Freeze base model for the first stage (train only the head)
base_model.trainable = False

inputs = keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs, name="xception_Breast_Cancer")

# -------------------- Compile (Stage 1: Train Head) --------------------
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=HEAD_LR),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="auc")
    ]
)

model.summary()

# -------------------- Callbacks --------------------
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=PATIENCE,
        restore_best_weights=True
    ),
    keras.callbacks.ModelCheckpoint(
        filepath=BEST_MODEL_H5,
        monitor="val_loss",
        save_best_only=True
    )
]

# -------------------- Train (Stage 1) --------------------
history_head = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# -------------------- Fine-Tuning (Stage 2) --------------------
history_ft = None
if DO_FINE_TUNE:
    # Unfreeze last N layers (keep BatchNorm frozen for stability)
    base_model.trainable = True

    # Freeze all layers first
    for layer in base_model.layers:
        layer.trainable = False

    # Unfreeze last N layers except BatchNorm
    for layer in base_model.layers[-FINE_TUNE_LAYERS:]:
        if isinstance(layer, layers.BatchNormalization):
            layer.trainable = False
        else:
            layer.trainable = True

    # Re-compile with a smaller learning rate
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.AUC(name="auc")
        ]
    )

    print("\nStarting fine-tuning...\n")
    history_ft = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FINE_TUNE_EPOCHS,
        callbacks=callbacks
    )

# -------------------- Save Models (.h5) --------------------
# Save base model (feature extractor) and full model (end-to-end classifier)
base_model.save(BASE_MODEL_H5)
model.save(FULL_MODEL_H5)
print(f"Saved base model: {BASE_MODEL_H5}")
print(f"Saved full model: {FULL_MODEL_H5}")
print(f"Best checkpoint (val_loss): {BEST_MODEL_H5}")

# -------------------- Combine History (for plotting) --------------------
def merge_histories(h1, h2):
    """Merge two Keras History objects (head + fine-tune) into one dict."""
    out = {}
    for k in h1.history.keys():
        out[k] = list(h1.history[k])
    if h2 is not None:
        for k in h2.history.keys():
            out[k].extend(list(h2.history[k]))
    return out

hist = merge_histories(history_head, history_ft)

# -------------------- Plot Training Curves --------------------
plt.figure(figsize=(10, 4))

# Loss
plt.plot(hist["loss"], label="Train Loss")
plt.plot(hist["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
# Accuracy
plt.plot(hist["accuracy"], label="Train Accuracy")
plt.plot(hist["val_accuracy"], label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.show()

# -------------------- Evaluate on Test Set --------------------
test_loss, test_acc, test_auc = model.evaluate(test_ds, verbose=1)
print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test AUC: {test_auc:.4f}\n")

# -------------------- Predictions for Confusion Matrix / ROC --------------------
y_true = []
y_prob = []

for x_batch, y_batch in test_ds:
    probs = model.predict(x_batch, verbose=0).reshape(-1)
    y_prob.extend(probs.tolist())
    y_true.extend(y_batch.numpy().astype(int).reshape(-1).tolist())

y_true = np.array(y_true)
y_prob = np.array(y_prob)

# Default threshold
threshold = 0.5
y_pred = (y_prob >= threshold).astype(int)

# -------------------- Confusion Matrix --------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5, 4))
plt.imshow(cm)
plt.title("Confusion Matrix (Test Set)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks([0, 1], class_names, rotation=20)
plt.yticks([0, 1], class_names)

# Put numbers in cells
for i in range(2):
    for j in range(2):
        plt.text(j, i, str(cm[i, j]), ha="center", va="center")

plt.colorbar()
plt.show()

print("Classification Report (Test Set):")
print(classification_report(y_true, y_pred, target_names=class_names))

# -------------------- ROC Curve --------------------
fpr, tpr, _ = roc_curve(y_true, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], linestyle="--", label="Random baseline")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Test Set)")
plt.legend()
plt.show()

# -------------------- One Example Inference --------------------
# Take 1 batch from test set
for images, labels in test_ds.take(1):
    img = images[0]
    true_label = int(labels[0].numpy())

    prob = float(model.predict(tf.expand_dims(img, 0), verbose=0)[0][0])
    pred_label = int(prob >= threshold)

    plt.figure(figsize=(4, 4))
    plt.imshow(img.numpy().astype("uint8"))
    plt.title(
        f"True: {class_names[true_label]} | Pred: {class_names[pred_label]} | Prob: {prob:.3f}"
    )
    plt.axis("off")
    plt.show()
    break
# Out:
# Found 1006 files belonging to 2 classes.
# Found 202 files belonging to 2 classes.
# Found 805 files belonging to 2 classes.
# Class names: ['benign', 'malignant']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "xception_Breast_Cancer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 7, 7, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         2,049 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,863,529 (79.59 MB)
#  Trainable params: 2,049 (8.00 KB)
#  Non-trainable params: 20,861,480 (79.58 MB)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6759 - auc: 0.6242 - loss: 0.6007
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.6778 - auc: 0.6263 - loss: 0.5995 - val_accuracy: 0.7376 - val_auc: 0.7393 - val_loss: 0.5390
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7608 - auc: 0.7888 - loss: 0.4973
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 95ms/step - accuracy: 0.7615 - auc: 0.7898 - loss: 0.4967 - val_accuracy: 0.7871 - val_auc: 0.7723 - val_loss: 0.5121
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.8285 - auc: 0.8668 - loss: 0.4232 - val_accuracy: 0.7871 - val_auc: 0.7885 - val_loss: 0.5168
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8384 - auc: 0.8744 - loss: 0.4061
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.8386 - auc: 0.8743 - loss: 0.4061 - val_accuracy: 0.7970 - val_auc: 0.8041 - val_loss: 0.5018
# Epoch 5/100
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8407 - auc: 0.9035 - loss: 0.3644
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.8406 - auc: 0.9028 - loss: 0.3655 - val_accuracy: 0.7970 - val_auc: 0.8198 - val_loss: 0.4724
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8388 - auc: 0.8847 - loss: 0.3819
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.8391 - auc: 0.8852 - loss: 0.3814 - val_accuracy: 0.8168 - val_auc: 0.8267 - val_loss: 0.4690
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.8312 - auc: 0.8888 - loss: 0.3935 - val_accuracy: 0.8119 - val_auc: 0.8287 - val_loss: 0.4746
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.8794 - auc: 0.9268 - loss: 0.3350 - val_accuracy: 0.8119 - val_auc: 0.8341 - val_loss: 0.4724
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8688 - auc: 0.9317 - loss: 0.3347
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.8687 - auc: 0.9312 - loss: 0.3350 - val_accuracy: 0.8119 - val_auc: 0.8391 - val_loss: 0.4638
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8735 - auc: 0.9362 - loss: 0.3208
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.8731 - auc: 0.9358 - loss: 0.3212 - val_accuracy: 0.8119 - val_auc: 0.8469 - val_loss: 0.4635
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.
# Epoch 20/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9671 - auc: 0.9964 - loss: 0.0763 - val_accuracy: 0.9059 - val_auc: 0.9480 - val_loss: 0.3094
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved base model: /content/drive/MyDrive/DATASETS/cancer/model-saved/random-save/xception_base_model.h5
# Saved full model: /content/drive/MyDrive/DATASETS/cancer/model-saved/random-save/xception_full_model.h5
# Best checkpoint (val_loss): /content/drive/MyDrive/DATASETS/cancer/model-saved/random-save/xception_best_model.h5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.9067 - auc: 0.7198 - loss: 0.2270
#
# Test Loss: 0.1649
# Test Accuracy: 0.9329
# Test AUC: 0.9780
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#       benign       0.90      0.88      0.89       249
#    malignant       0.95      0.96      0.95       556
#
#     accuracy                           0.93       805
#    macro avg       0.92      0.92      0.92       805
# weighted avg       0.93      0.93      0.93       805
# /tmp/ipython-input-2614888754.py:291: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   true_label = int(labels[0].numpy())

# %% [markdown]
#  ## MIGT selected sapmles with grayscale images

# %%
# -------------------- Imports --------------------
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# -------------------- Configuration --------------------
BASE_DIR = "/content/drive/MyDrive/DATASETS/cancer/MIGT-DATASET"
TRAIN_DIR = os.path.join(BASE_DIR, "train")
VAL_DIR   = os.path.join(BASE_DIR, "val")
TEST_DIR  = os.path.join(BASE_DIR, "test")

IMG_SIZE = (224, 224)   # Xception expects 224x224
BATCH_SIZE = 32
EPOCHS = 100
PATIENCE = 6
SEED = 42

# Fine-tuning config
DO_FINE_TUNE = True
FINE_TUNE_LAYERS = 30         # unfreeze last N layers of Xception
HEAD_LR = 1e-3
FINE_TUNE_LR = 1e-5
FINE_TUNE_EPOCHS = 20         # additional epochs after head training

# Model save paths (Drive)
SAVE_DIR = "/content/drive/MyDrive/DATASETS/cancer/model-saved/MIGT-GRAYSCALE-save"
os.makedirs(SAVE_DIR, exist_ok=True)
BASE_MODEL_H5 = os.path.join(SAVE_DIR, "xception_base_model.h5")
FULL_MODEL_H5 = os.path.join(SAVE_DIR, "xception_full_model.h5")
BEST_MODEL_H5 = os.path.join(SAVE_DIR, "xception_best_model.h5")

# -------------------- Safety Checks --------------------
for d in [TRAIN_DIR, VAL_DIR, TEST_DIR]:
    if not os.path.isdir(d):
        raise FileNotFoundError(
            f"Missing folder: {d}\n\n"
            "Expected structure:\n"
            "BASE_DIR/train/<class_name>/...\n"
            "BASE_DIR/val/<class_name>/...\n"
            "BASE_DIR/test/<class_name>/...\n"
        )

# -------------------- Load Datasets --------------------
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"  # returns labels as 0/1
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=False  # IMPORTANT for correct ROC/CM alignment
)

class_names = train_ds.class_names
print("Class names:", class_names)

# We'll respect this order everywhere.

# -------------------- Performance: Cache/Prefetch --------------------
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000, seed=SEED).prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)
test_ds = test_ds.prefetch(AUTOTUNE)

# -------------------- Data Augmentation --------------------
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.10),
        layers.RandomZoom(0.15),
        layers.RandomContrast(0.10),
    ],
    name="data_augmentation"
)

# Xception preprocess (ImageNet)
preprocess_input = tf.keras.applications.xception.preprocess_input

# -------------------- Build Model --------------------
base_model = tf.keras.applications.Xception(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

# Freeze base model for the first stage (train only the head)
base_model.trainable = False

inputs = keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs, name="xception_Breast_Cancer")

# -------------------- Compile (Stage 1: Train Head) --------------------
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=HEAD_LR),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="auc")
    ]
)

model.summary()

# -------------------- Callbacks --------------------
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=PATIENCE,
        restore_best_weights=True
    ),
    keras.callbacks.ModelCheckpoint(
        filepath=BEST_MODEL_H5,
        monitor="val_loss",
        save_best_only=True
    )
]

# -------------------- Train (Stage 1) --------------------
history_head = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# -------------------- Fine-Tuning (Stage 2) --------------------
history_ft = None
if DO_FINE_TUNE:
    # Unfreeze last N layers (keep BatchNorm frozen for stability)
    base_model.trainable = True

    # Freeze all layers first
    for layer in base_model.layers:
        layer.trainable = False

    # Unfreeze last N layers except BatchNorm
    for layer in base_model.layers[-FINE_TUNE_LAYERS:]:
        if isinstance(layer, layers.BatchNormalization):
            layer.trainable = False
        else:
            layer.trainable = True

    # Re-compile with a smaller learning rate
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.AUC(name="auc")
        ]
    )

    print("\nStarting fine-tuning...\n")
    history_ft = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FINE_TUNE_EPOCHS,
        callbacks=callbacks
    )

# -------------------- Save Models (.h5) --------------------
# Save base model (feature extractor) and full model (end-to-end classifier)
base_model.save(BASE_MODEL_H5)
model.save(FULL_MODEL_H5)
print(f"Saved base model: {BASE_MODEL_H5}")
print(f"Saved full model: {FULL_MODEL_H5}")
print(f"Best checkpoint (val_loss): {BEST_MODEL_H5}")

# -------------------- Combine History (for plotting) --------------------
def merge_histories(h1, h2):
    """Merge two Keras History objects (head + fine-tune) into one dict."""
    out = {}
    for k in h1.history.keys():
        out[k] = list(h1.history[k])
    if h2 is not None:
        for k in h2.history.keys():
            out[k].extend(list(h2.history[k]))
    return out

hist = merge_histories(history_head, history_ft)

# -------------------- Plot Training Curves --------------------
plt.figure(figsize=(10, 4))

# Loss
plt.plot(hist["loss"], label="Train Loss")
plt.plot(hist["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
# Accuracy
plt.plot(hist["accuracy"], label="Train Accuracy")
plt.plot(hist["val_accuracy"], label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.show()

# -------------------- Evaluate on Test Set --------------------
test_loss, test_acc, test_auc = model.evaluate(test_ds, verbose=1)
print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test AUC: {test_auc:.4f}\n")

# -------------------- Predictions for Confusion Matrix / ROC --------------------
y_true = []
y_prob = []

for x_batch, y_batch in test_ds:
    probs = model.predict(x_batch, verbose=0).reshape(-1)
    y_prob.extend(probs.tolist())
    y_true.extend(y_batch.numpy().astype(int).reshape(-1).tolist())

y_true = np.array(y_true)
y_prob = np.array(y_prob)

# Default threshold
threshold = 0.5
y_pred = (y_prob >= threshold).astype(int)

# -------------------- Confusion Matrix --------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5, 4))
plt.imshow(cm)
plt.title("Confusion Matrix (Test Set)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks([0, 1], class_names, rotation=20)
plt.yticks([0, 1], class_names)

# Put numbers in cells
for i in range(2):
    for j in range(2):
        plt.text(j, i, str(cm[i, j]), ha="center", va="center")

plt.colorbar()
plt.show()

print("Classification Report (Test Set):")
print(classification_report(y_true, y_pred, target_names=class_names))

# -------------------- ROC Curve --------------------
fpr, tpr, _ = roc_curve(y_true, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], linestyle="--", label="Random baseline")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Test Set)")
plt.legend()
plt.show()

# -------------------- One Example Inference --------------------
# Take 1 batch from test set
for images, labels in test_ds.take(1):
    img = images[0]
    true_label = int(labels[0].numpy())

    prob = float(model.predict(tf.expand_dims(img, 0), verbose=0)[0][0])
    pred_label = int(prob >= threshold)

    plt.figure(figsize=(4, 4))
    plt.imshow(img.numpy().astype("uint8"))
    plt.title(
        f"True: {class_names[true_label]} | Pred: {class_names[pred_label]} | Prob: {prob:.3f}"
    )
    plt.axis("off")
    plt.show()
    break
# Out:
# Found 1000 files belonging to 2 classes.
# Found 208 files belonging to 2 classes.
# Found 800 files belonging to 2 classes.
# Class names: ['benign', 'malignant']
# Model: "xception_Breast_Cancer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_10 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_3 (TrueDivide)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract_3 (Subtract)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 7, 7, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │         2,049 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,863,529 (79.59 MB)
#  Trainable params: 2,049 (8.00 KB)
#  Non-trainable params: 20,861,480 (79.58 MB)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6996 - auc: 0.7029 - loss: 0.5667
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 199ms/step - accuracy: 0.7007 - auc: 0.7047 - loss: 0.5654 - val_accuracy: 0.7692 - val_auc: 0.7498 - val_loss: 0.5313
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7954 - auc: 0.8368 - loss: 0.4701
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.7956 - auc: 0.8368 - loss: 0.4697 - val_accuracy: 0.7740 - val_auc: 0.7955 - val_loss: 0.5099
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8385 - auc: 0.8786 - loss: 0.4052
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8383 - auc: 0.8787 - loss: 0.4051 - val_accuracy: 0.7788 - val_auc: 0.8286 - val_loss: 0.4634
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8343 - auc: 0.8859 - loss: 0.3949
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8343 - auc: 0.8859 - loss: 0.3948 - val_accuracy: 0.7788 - val_auc: 0.8424 - val_loss: 0.4560
# Epoch 5/100
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8363 - auc: 0.9036 - loss: 0.3655
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - accuracy: 0.9410 - auc: 0.9836 - loss: 0.1434 - val_accuracy: 0.9038 - val_auc: 0.9546 - val_loss: 0.2462
# Epoch 12/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9341 - auc: 0.9833 - loss: 0.1609 - val_accuracy: 0.8942 - val_auc: 0.9497 - val_loss: 0.2829
# Epoch 13/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.9510 - auc: 0.9880 - loss: 0.1293 - val_accuracy: 0.9038 - val_auc: 0.9554 - val_loss: 0.2554
# Epoch 14/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9557 - auc: 0.9901 - loss: 0.1221
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 199ms/step - accuracy: 0.9555 - auc: 0.9900 - loss: 0.1224 - val_accuracy: 0.9038 - val_auc: 0.9610 - val_loss: 0.2356
# Epoch 15/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9581 - auc: 0.9899 - loss: 0.1250
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 125ms/step - accuracy: 0.9580 - auc: 0.9898 - loss: 0.1251 - val_accuracy: 0.9087 - val_auc: 0.9641 - val_loss: 0.2289
# Epoch 16/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 212ms/step - accuracy: 0.9454 - auc: 0.9878 - loss: 0.1283 - val_accuracy: 0.9231 - val_auc: 0.9634 - val_loss: 0.2327
# Epoch 17/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9553 - auc: 0.9897 - loss: 0.1199 - val_accuracy: 0.9038 - val_auc: 0.9582 - val_loss: 0.2593
# Epoch 18/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9596 - auc: 0.9944 - loss: 0.0971 - val_accuracy: 0.9183 - val_auc: 0.9620 - val_loss: 0.2405
# Epoch 19/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - accuracy: 0.9412 - auc: 0.9881 - loss: 0.1312 - val_accuracy: 0.9183 - val_auc: 0.9627 - val_loss: 0.2384
# Epoch 20/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9474 - auc: 0.9906 - loss: 0.1180
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 211ms/step - accuracy: 0.9476 - auc: 0.9907 - loss: 0.1177 - val_accuracy: 0.9231 - val_auc: 0.9642 - val_loss: 0.2157
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved base model: /content/drive/MyDrive/DATASETS/cancer/model-saved/MIGT-GRAYSCALE-save/xception_base_model.h5
# Saved full model: /content/drive/MyDrive/DATASETS/cancer/model-saved/MIGT-GRAYSCALE-save/xception_full_model.h5
# Best checkpoint (val_loss): /content/drive/MyDrive/DATASETS/cancer/model-saved/MIGT-GRAYSCALE-save/xception_best_model.h5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.8988 - auc: 0.7082 - loss: 0.2601
#
# Test Loss: 0.1861
# Test Accuracy: 0.9312
# Test AUC: 0.9735
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#       benign       0.91      0.86      0.89       248
#    malignant       0.94      0.96      0.95       552
#
#     accuracy                           0.93       800
#    macro avg       0.93      0.91      0.92       800
# weighted avg       0.93      0.93      0.93       800
# /tmp/ipython-input-1068067352.py:291: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   true_label = int(labels[0].numpy())

# %% [markdown]
# MIGT-RGB

# %%
# -------------------- Imports --------------------
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# -------------------- Configuration --------------------
BASE_DIR = "/content/drive/MyDrive/DATASETS/cancer/MIGT_DATASET_RGB"
TRAIN_DIR = os.path.join(BASE_DIR, "train")
VAL_DIR   = os.path.join(BASE_DIR, "val")
TEST_DIR  = os.path.join(BASE_DIR, "test")

IMG_SIZE = (224, 224)   # Xception expects 224x224
BATCH_SIZE = 32
EPOCHS = 100
PATIENCE = 6
SEED = 42

# Fine-tuning config
DO_FINE_TUNE = True
FINE_TUNE_LAYERS = 30         # unfreeze last N layers of Xception
HEAD_LR = 1e-3
FINE_TUNE_LR = 1e-5
FINE_TUNE_EPOCHS = 20         # additional epochs after head training

# Model save paths (Drive)
SAVE_DIR = "/content/drive/MyDrive/DATASETS/cancer/model-saved/MIGT-RGB-save"
os.makedirs(SAVE_DIR, exist_ok=True)
BASE_MODEL_H5 = os.path.join(SAVE_DIR, "xception_base_model.h5")
FULL_MODEL_H5 = os.path.join(SAVE_DIR, "xception_full_model.h5")
BEST_MODEL_H5 = os.path.join(SAVE_DIR, "xception_best_model.h5")

# -------------------- Safety Checks --------------------
for d in [TRAIN_DIR, VAL_DIR, TEST_DIR]:
    if not os.path.isdir(d):
        raise FileNotFoundError(
            f"Missing folder: {d}\n\n"
            "Expected structure:\n"
            "BASE_DIR/train/<class_name>/...\n"
            "BASE_DIR/val/<class_name>/...\n"
            "BASE_DIR/test/<class_name>/...\n"
        )

# -------------------- Load Datasets --------------------
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"  # returns labels as 0/1
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=False  # IMPORTANT for correct ROC/CM alignment
)

class_names = train_ds.class_names
print("Class names:", class_names)



# -------------------- Performance: Cache/Prefetch --------------------
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000, seed=SEED).prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)
test_ds = test_ds.prefetch(AUTOTUNE)

# -------------------- Data Augmentation --------------------
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.10),
        layers.RandomZoom(0.15),
        layers.RandomContrast(0.10),
    ],
    name="data_augmentation"
)

# Xception preprocess (ImageNet)
preprocess_input = tf.keras.applications.xception.preprocess_input

# -------------------- Build Model --------------------
base_model = tf.keras.applications.Xception(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
)

# Freeze base model for the first stage (train only the head)
base_model.trainable = False

inputs = keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs, name="xception_Breast_Cancer")

# -------------------- Compile (Stage 1: Train Head) --------------------
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=HEAD_LR),
    loss="binary_crossentropy",
    metrics=[
        "accuracy",
        tf.keras.metrics.AUC(name="auc")
    ]
)

model.summary()

# -------------------- Callbacks --------------------
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=PATIENCE,
        restore_best_weights=True
    ),
    keras.callbacks.ModelCheckpoint(
        filepath=BEST_MODEL_H5,
        monitor="val_loss",
        save_best_only=True
    )
]

# -------------------- Train (Stage 1) --------------------
history_head = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# -------------------- Fine-Tuning (Stage 2) --------------------
history_ft = None
if DO_FINE_TUNE:
    # Unfreeze last N layers (keep BatchNorm frozen for stability)
    base_model.trainable = True

    # Freeze all layers first
    for layer in base_model.layers:
        layer.trainable = False

    # Unfreeze last N layers except BatchNorm
    for layer in base_model.layers[-FINE_TUNE_LAYERS:]:
        if isinstance(layer, layers.BatchNormalization):
            layer.trainable = False
        else:
            layer.trainable = True

    # Re-compile with a smaller learning rate
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.AUC(name="auc")
        ]
    )

    print("\nStarting fine-tuning...\n")
    history_ft = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FINE_TUNE_EPOCHS,
        callbacks=callbacks
    )

# -------------------- Save Models (.h5) --------------------
# Save base model (feature extractor) and full model (end-to-end classifier)
base_model.save(BASE_MODEL_H5)
model.save(FULL_MODEL_H5)
print(f"Saved base model: {BASE_MODEL_H5}")
print(f"Saved full model: {FULL_MODEL_H5}")
print(f"Best checkpoint (val_loss): {BEST_MODEL_H5}")

# -------------------- Combine History (for plotting) --------------------
def merge_histories(h1, h2):
    """Merge two Keras History objects (head + fine-tune) into one dict."""
    out = {}
    for k in h1.history.keys():
        out[k] = list(h1.history[k])
    if h2 is not None:
        for k in h2.history.keys():
            out[k].extend(list(h2.history[k]))
    return out

hist = merge_histories(history_head, history_ft)

# -------------------- Plot Training Curves --------------------
plt.figure(figsize=(10, 4))

# Loss
plt.plot(hist["loss"], label="Train Loss")
plt.plot(hist["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
# Accuracy
plt.plot(hist["accuracy"], label="Train Accuracy")
plt.plot(hist["val_accuracy"], label="Val Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.show()

# -------------------- Evaluate on Test Set --------------------
test_loss, test_acc, test_auc = model.evaluate(test_ds, verbose=1)
print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test AUC: {test_auc:.4f}\n")

# -------------------- Predictions for Confusion Matrix / ROC --------------------
y_true = []
y_prob = []

for x_batch, y_batch in test_ds:
    probs = model.predict(x_batch, verbose=0).reshape(-1)
    y_prob.extend(probs.tolist())
    y_true.extend(y_batch.numpy().astype(int).reshape(-1).tolist())

y_true = np.array(y_true)
y_prob = np.array(y_prob)

# Default threshold
threshold = 0.5
y_pred = (y_prob >= threshold).astype(int)

# -------------------- Confusion Matrix --------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5, 4))
plt.imshow(cm)
plt.title("Confusion Matrix (Test Set)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks([0, 1], class_names, rotation=20)
plt.yticks([0, 1], class_names)

# Put numbers in cells
for i in range(2):
    for j in range(2):
        plt.text(j, i, str(cm[i, j]), ha="center", va="center")

plt.colorbar()
plt.show()

print("Classification Report (Test Set):")
print(classification_report(y_true, y_pred, target_names=class_names))

# -------------------- ROC Curve --------------------
fpr, tpr, _ = roc_curve(y_true, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], linestyle="--", label="Random baseline")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Test Set)")
plt.legend()
plt.show()

# -------------------- One Example Inference --------------------
# Take 1 batch from test set
for images, labels in test_ds.take(1):
    img = images[0]
    true_label = int(labels[0].numpy())

    prob = float(model.predict(tf.expand_dims(img, 0), verbose=0)[0][0])
    pred_label = int(prob >= threshold)

    plt.figure(figsize=(4, 4))
    plt.imshow(img.numpy().astype("uint8"))
    plt.title(
        f"True: {class_names[true_label]} | Pred: {class_names[pred_label]} | Prob: {prob:.3f}"
    )
    plt.axis("off")
    plt.show()
    break
# Out:
# Found 1000 files belonging to 2 classes.
# Found 208 files belonging to 2 classes.
# Found 800 files belonging to 2 classes.
# Class names: ['benign', 'malignant']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "xception_Breast_Cancer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ xception (Functional)           │ (None, 7, 7, 2048)     │    20,861,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         2,049 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,863,529 (79.59 MB)
#  Trainable params: 2,049 (8.00 KB)
#  Non-trainable params: 20,861,480 (79.58 MB)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6421 - auc: 0.6020 - loss: 0.6171
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 77s 779ms/step - accuracy: 0.6440 - auc: 0.6048 - loss: 0.6156 - val_accuracy: 0.8077 - val_auc: 0.8470 - val_loss: 0.4603
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8111 - auc: 0.8236 - loss: 0.4796
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 96ms/step - accuracy: 0.8108 - auc: 0.8236 - loss: 0.4793 - val_accuracy: 0.8173 - val_auc: 0.8787 - val_loss: 0.4214
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8274 - auc: 0.8424 - loss: 0.4335
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8275 - auc: 0.8427 - loss: 0.4332 - val_accuracy: 0.8221 - val_auc: 0.8889 - val_loss: 0.3996
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8387 - auc: 0.8720 - loss: 0.4053
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8387 - auc: 0.8720 - loss: 0.4052 - val_accuracy: 0.8221 - val_auc: 0.8958 - val_loss: 0.3908
# Epoch 5/100
# 31/32 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8535 - auc: 0.8883 - loss: 0.3740
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.8526 - auc: 0.8879 - loss: 0.3747 - val_accuracy: 0.8558 - val_auc: 0.9099 - val_loss: 0.3639
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.8573 - auc: 0.8962 - loss: 0.3748 - val_accuracy: 0.8558 - val_auc: 0.9149 - val_loss: 0.3689
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8428 - auc: 0.9029 - loss: 0.3629
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.8427 - auc: 0.9027 - loss: 0.3628 - val_accuracy: 0.8558 - val_auc: 0.9191 - val_loss: 0.3498
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8585 - auc: 0.9017 - loss: 0.3644
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8584 - auc: 0.9017 - loss: 0.3642 - val_accuracy: 0.8702 - val_auc: 0.9229 - val_loss: 0.3419
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8253 - auc: 0.8828 - loss: 0.3752
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.8258 - auc: 0.8833 - loss: 0.3749 - val_accuracy: 0.8750 - val_auc: 0.9299 - val_loss: 0.3302
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8693 - auc: 0.9246 - loss: 0.3316
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.8691 - auc: 0.9246 - loss: 0.3317 - val_accuracy: 0.8702 - val_auc: 0.9313 - val_loss: 0.3229
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.8521 - auc: 0.9162 - loss: 0.3451 - val_accuracy: 0.8558 - val_auc: 0.9313 - val_loss: 0.3344
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.8530 - auc: 0.9135 - loss: 0.3511 - val_accuracy: 0.8558 - val_auc: 0.9338 - val_loss: 0.3267
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8675 - auc: 0.9269 - loss: 0.3260
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.8678 - auc: 0.9269 - loss: 0.3258 - val_accuracy: 0.8750 - val_auc: 0.9385 - val_loss: 0.3092
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8771 - auc: 0.9312 - loss: 0.3144
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.8769 - auc: 0.9311 - loss: 0.3145 - val_accuracy: 0.8750 - val_auc: 0.9398 - val_loss: 0.3070
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.8617 - auc: 0.9322 - loss: 0.3095 - val_accuracy: 0.8654 - val_auc: 0.9392 - val_loss: 0.3211
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.8886 - auc: 0.9313 - loss: 0.3084 - val_accuracy: 0.8702 - val_auc: 0.9415 - val_loss: 0.3085
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8821 - auc: 0.9469 - loss: 0.2879
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 123ms/step - accuracy: 0.9213 - auc: 0.9710 - loss: 0.2013 - val_accuracy: 0.8990 - val_auc: 0.9727 - val_loss: 0.1986
# Epoch 6/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9131 - auc: 0.9752 - loss: 0.1905
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - accuracy: 0.9130 - auc: 0.9751 - loss: 0.1907 - val_accuracy: 0.9327 - val_auc: 0.9762 - val_loss: 0.1831
# Epoch 7/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9338 - auc: 0.9716 - loss: 0.1881
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.9337 - auc: 0.9717 - loss: 0.1880 - val_accuracy: 0.9327 - val_auc: 0.9787 - val_loss: 0.1802
# Epoch 8/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9253 - auc: 0.9753 - loss: 0.1902 - val_accuracy: 0.9038 - val_auc: 0.9780 - val_loss: 0.2014
# Epoch 9/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9206 - auc: 0.9809 - loss: 0.1717
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.9209 - auc: 0.9809 - loss: 0.1716 - val_accuracy: 0.9279 - val_auc: 0.9807 - val_loss: 0.1654
# Epoch 10/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9476 - auc: 0.9868 - loss: 0.1432 - val_accuracy: 0.9135 - val_auc: 0.9805 - val_loss: 0.1920
# Epoch 11/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9340 - auc: 0.9847 - loss: 0.1545
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 214ms/step - accuracy: 0.9339 - auc: 0.9846 - loss: 0.1547 - val_accuracy: 0.9375 - val_auc: 0.9811 - val_loss: 0.1586
# Epoch 12/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9529 - auc: 0.9890 - loss: 0.1281
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.9527 - auc: 0.9890 - loss: 0.1281 - val_accuracy: 0.9423 - val_auc: 0.9821 - val_loss: 0.1573
# Epoch 13/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.9529 - auc: 0.9876 - loss: 0.1410 - val_accuracy: 0.9183 - val_auc: 0.9772 - val_loss: 0.1650
# Epoch 14/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - accuracy: 0.9338 - auc: 0.9868 - loss: 0.1417 - val_accuracy: 0.9327 - val_auc: 0.9772 - val_loss: 0.1579
# Epoch 15/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9535 - auc: 0.9908 - loss: 0.1189
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 0.9534 - auc: 0.9908 - loss: 0.1189 - val_accuracy: 0.9375 - val_auc: 0.9829 - val_loss: 0.1499
# Epoch 16/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.9485 - auc: 0.9875 - loss: 0.1346 - val_accuracy: 0.9231 - val_auc: 0.9815 - val_loss: 0.1634
# Epoch 17/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - accuracy: 0.9594 - auc: 0.9919 - loss: 0.1152 - val_accuracy: 0.9375 - val_auc: 0.9814 - val_loss: 0.1546
# Epoch 18/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9711 - auc: 0.9944 - loss: 0.0966 - val_accuracy: 0.9327 - val_auc: 0.9810 - val_loss: 0.1527
# Epoch 19/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9678 - auc: 0.9940 - loss: 0.0917
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - accuracy: 0.9676 - auc: 0.9940 - loss: 0.0919 - val_accuracy: 0.9471 - val_auc: 0.9882 - val_loss: 0.1260
# Epoch 20/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9501 - auc: 0.9931 - loss: 0.1047 - val_accuracy: 0.9423 - val_auc: 0.9821 - val_loss: 0.1373
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved base model: /content/drive/MyDrive/DATASETS/cancer/model-saved/MIGT-RGB-save/xception_base_model.h5
# Saved full model: /content/drive/MyDrive/DATASETS/cancer/model-saved/MIGT-RGB-save/xception_full_model.h5
# Best checkpoint (val_loss): /content/drive/MyDrive/DATASETS/cancer/model-saved/MIGT-RGB-save/xception_best_model.h5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.8951 - auc: 0.7017 - loss: 0.2786
#
# Test Loss: 0.2070
# Test Accuracy: 0.9262
# Test AUC: 0.9700
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#       benign       0.89      0.88      0.88       248
#    malignant       0.94      0.95      0.95       552
#
#     accuracy                           0.93       800
#    macro avg       0.91      0.91      0.91       800
# weighted avg       0.93      0.93      0.93       800
# /tmp/ipython-input-1590276216.py:291: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   true_label = int(labels[0].numpy())
