# %% [markdown]
# MIGT-RGB

# %%
# -------------------- Imports --------------------
import os
import yaml
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# -------------------- Load YAML --------------------
CONFIG_PATH = "configs/migt_rgb.yaml"
with open(CONFIG_PATH, "r") as f:
    cfg = yaml.safe_load(f)

# -------------------- Configuration --------------------
BASE_DIR = cfg["dataset"]["base_dir"]
TRAIN_DIR = os.path.join(BASE_DIR, cfg["dataset"]["train_dir"])
VAL_DIR   = os.path.join(BASE_DIR, cfg["dataset"]["val_dir"])
TEST_DIR  = os.path.join(BASE_DIR, cfg["dataset"]["test_dir"])

IMG_SIZE = tuple(cfg["data"]["img_size"])
BATCH_SIZE = cfg["data"]["batch_size"]
SEED = cfg["data"]["seed"]

EPOCHS = cfg["training"]["epochs"]
PATIENCE = cfg["training"]["patience"]
HEAD_LR = cfg["training"]["head_lr"]

DO_FINE_TUNE = cfg["fine_tuning"]["enabled"]
FINE_TUNE_LAYERS = cfg["fine_tuning"]["unfreeze_last_layers"]
FINE_TUNE_LR = cfg["fine_tuning"]["lr"]
FINE_TUNE_EPOCHS = cfg["fine_tuning"]["epochs"]

SAVE_DIR = cfg["output"]["save_dir"]
os.makedirs(SAVE_DIR, exist_ok=True)

BASE_MODEL_H5 = os.path.join(SAVE_DIR, "xception_base_model.h5")
FULL_MODEL_H5 = os.path.join(SAVE_DIR, "xception_full_model.h5")
BEST_MODEL_H5 = os.path.join(SAVE_DIR, "xception_best_model.h5")

# -------------------- Safety Checks --------------------
for d in [TRAIN_DIR, VAL_DIR, TEST_DIR]:
    if not os.path.isdir(d):
        raise FileNotFoundError(f"Missing folder: {d}")

# -------------------- Load Datasets --------------------
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="binary",
    shuffle=False
)

class_names = train_ds.class_names
print("Classes:", class_names)

# -------------------- Performance --------------------
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000, seed=SEED).prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)
test_ds = test_ds.prefetch(AUTOTUNE)

# -------------------- Data Augmentation --------------------
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.10),
    layers.RandomZoom(0.15),
    layers.RandomContrast(0.10),
])

preprocess_input = tf.keras.applications.xception.preprocess_input

# -------------------- Build Model --------------------
base_model = tf.keras.applications.Xception(
    weights="imagenet",
    include_top=False,
    input_shape=(*IMG_SIZE, 3)
)
base_model.trainable = False

inputs = keras.Input(shape=(*IMG_SIZE, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)

model = keras.Model(inputs, outputs)

# -------------------- Compile (Stage 1) --------------------
model.compile(
    optimizer=keras.optimizers.Adam(HEAD_LR),
    loss="binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
)

callbacks = [
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights=True),
    keras.callbacks.ModelCheckpoint(BEST_MODEL_H5, monitor="val_loss", save_best_only=True)
]

history_head = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# -------------------- Fine-tuning --------------------
if DO_FINE_TUNE:
    for layer in base_model.layers:
        layer.trainable = False

    for layer in base_model.layers[-FINE_TUNE_LAYERS:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    model.compile(
        optimizer=keras.optimizers.Adam(FINE_TUNE_LR),
        loss="binary_crossentropy",
        metrics=["accuracy", tf.keras.metrics.AUC(name="auc")]
    )

    model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=FINE_TUNE_EPOCHS,
        callbacks=callbacks
    )

# -------------------- Save --------------------
base_model.save(BASE_MODEL_H5)
model.save(FULL_MODEL_H5)
# Out:
# Found 1000 files belonging to 2 classes.
# Found 208 files belonging to 2 classes.
# Found 800 files belonging to 2 classes.
# Class names: ['benign', 'malignant']
# ...
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "xception_Breast_Cancer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
pip freeze > requirements.txt

# %%
from google.colab import files
files.download("requirements.txt")

# %%
pip freeze | grep -E "tensorflow|numpy|scikit-learn|matplotlib|pyyaml|tqdm" > requirements.txt
